# %% [markdown]
# # SHP2CSV algorithm
# ## Importing libraries

# %%
from shapely.geometry import shape
from shapely.ops import unary_union
import fiona
import networkx as nx
import itertools
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing and reading shp file

# %%
geoms =[shape(feature['geometry']) for feature in fiona.open("shp/Bogota_2.shp") if feature['geometry'] != None]

# %% [markdown]
# ## Converting `geoms` into a planar graph

# %%
res = unary_union(geoms)

# %% [markdown]
# ## Creating a Graph object in order to print it
# this part of the code is not needed, it is just for having an idea of the graph that is going to be exported

# %%
G = nx.Graph()
for line in res:
    for seg_start, seg_end in itertools.izip(list(line.coords),list(line.coords)[1:]):
        G.add_edge(seg_start, seg_end)

# %% [markdown]
# ## Plotting the graph

# %%
nx.draw(G, node_size=1)
plt.show()

# %% [markdown]
# ## Creating sets

# %%
y = set()
x = set()
lengths = set()

nodes = set()
edges = set()

nodes_norm = list()
edges_norm = set()

# %% [markdown]
# ## Creating a list of nodes

# %%
for line in res:
    for node in line.coords:
        nodes.add(node)
        x.add(node[0])
        y.add(node[1])

nodes = list(nodes)

# %% [markdown]
# ## Normalizing the nodes coordinates

# %%
# Getting the max and min for x and y axis
x_max = max(x)
x_min = min(x)
y_max = max(y)
y_min = min(y)

# Normalizing

for node in nodes:
    node = (nodes.index(node),(node[0]-x_min)/(x_max-x_min),(node[1]-y_min)/(y_max-y_min))
    nodes_norm.append(node)

# %% [markdown]
# ## Creating a list of edges

# %%
from IPython.core.debugger import Tracer
for line in res:
    #Tracer()()
    #print(line)
    last_coord = line
    lenght = len(line.coords)
    for coord in line.coords:
        if last_coord != None:
            edge = (nodes.index(last_coord),nodes.index(coord),line.length)
            lengths.add(line.length)/lenght #modify this
            edges.add(edge)
        last_coord = coord
        
    
edges = list(edges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-42f75012024f> in <module>()
#       7     for coord in line.coords:
#       8         if last_coord != None:
# ----> 9             edge = (nodes.index(last_coord),nodes.index(coord),line.length)
#      10             lengths.add(line.length)/lenght #modify this
#      11             edges.add(edge)
#
# ValueError: <shapely.geometry.linestring.LineString object at 0x101b54c90> is not in list

# %% [markdown]
# ## Normalizing the cost of the edges

# %%
length_max = max(lengths)
length_min = min(lengths)

# normalizing length
for edge in edges:
    edge2 = (edges.index(edge),edge[0],edge[1],(edge[2]-length_min)/(length_max-length_min))
    edges_norm.add(edge2)

# %% [markdown]
# ## printing results

# %%
nodes_norm
# Out:
# [(0, 0.6949488123836981, 0.7729146537898857),
#  (1, 0.9097196218489396, 0.6654254929344839),
#  (2, 0.5351429304230931, 0.6145903997888157),
#  (3, 0.9499388109276139, 0.9299729959060011),
#  (4, 0.7852031479566833, 0.2859983329376445),
#  (5, 0.9999639446810009, 0.9398737377548904),
#  (6, 0.7810696416465216, 0.2906741004424609),
#  (7, 0.798511383763463, 0.329691776439599),
#  (8, 0.7439621287731479, 0.38420273896331125),
#  (9, 0.9798292978915487, 0.8564520535826502),
#  (10, 0.6088203457670779, 0.11924824083201851),
#  (11, 0.7739042969622385, 0.3167595571402254),
#  (304, 0.9548334208306547, 0.9674917818756339),
#  (305, 0.3453335571683549, 0.4647759272748159),
#  (306, 0.7730428346106271, 0.2997810497551848),
#  (307, 0.0, 0.47568697088588613),
#  (308, 0.15650356588553258, 0.519316999134307),
#  (309, 0.36041439752946713, 0.30795641105520505),
#  (310, 0.6892224075273274, 0.7524731834403087),
#  (311, 0.6673116183957681, 0.12811457502126575),
#  (312, 0.7747320406556628, 0.315263694188805),
#  (313, 0.07439998479485875, 0.38151102490539246)]

# %%
edges_norm
# Out:
# {(0, 305, 266, 0.08109586726864043),
#  (1, 227, 47, 0.06370263181207332),
#  (2, 252, 278, 0.10176529007465654),
#  (3, 251, 151, 6.383776795402204e-07),
#  (4, 259, 288, 0.3978511745977702),
#  (5, 125, 258, 0.17946310104309365),
#  (6, 107, 92, 0.2836224393628342),
#  (7, 173, 94, 5.593434873683475e-14),
#  (8, 126, 185, 0.688877612837282),
#  (9, 107, 2, 0.07876098478814894),
#  (10, 220, 259, 0.10753163437332972),
#  (11, 251, 242, 0.3994942934300406),
#  (12, 2, 199, 0.26757485111053536),
#  (13, 298, 107, 3.137928401799632e-08),
#  (14, 94, 112, 0.23254721505404344),
#  (15, 110, 281, 0.04304953803082558),
#  (16, 110, 8, 0.04967561359508926),
#  (17, 2, 285, 0.3778692670824175),
#  (18, 141, 262, 1.0),
#  (19, 11, 213, 0.09207631091166994),
#  (20, 133, 35, 0.0002838774016229521),
#  (21, 217, 267, 0.06594553921584487),
#  (22, 225, 143, 0.2733412234892031),
#  (23, 305, 165, 0.05705195649230259),
#  (24, 192, 70, 0.28960963067389334),
#  (25, 194, 67, 0.4681982762132309),
#  (26, 192, 309, 0.19269438746858997),
#  (27, 86, 141, 4.8410898474837025e-08),
#  (28, 141, 208, 0.00042256950522591696),
#  (29, 165, 58, 0.29010075755139236),
#  (30, 238, 232, 0.3953465140773574),
#  (31, 3, 223, 0.40180947119132776),
#  (32, 208, 3, 0.0468732295610797),
#  (33, 165, 123, 0.24286793953376654),
#  (34, 106, 251, 0.019901117435984404),
#  (35, 91, 125, 0.013166103608318751),
#  (36, 220, 179, 0.9890802446471122),
#  (37, 238, 147, 0.3192057528393438),
#  (38, 133, 34, 0.056354181880101994),
#  (39, 217, 60, 0.34907811886050943),
#  (40, 269, 150, 0.12321686002174326),
#  (41, 194, 296, 0.15402490246294698),
#  (42, 133, 251, 0.02707289821364159),
#  (43, 106, 133, 0.02516643480444518),
#  (44, 103, 1, 0.33056497135356755),
#  (45, 126, 194, 7.951194960129021e-05),
#  (46, 281, 238, 0.30498126696202543),
#  (47, 94, 160, 0.0),
#  (48, 297, 217, 8.458539182002587e-08),
#  (49, 35, 48, 0.05155391798840605)}

# %% [markdown]
# ## Exporting results to csv

# %%
# Writing csv
import csv

# vertices
with open("vertices.csv", "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in nodes_norm:
        writer.writerow(val)
        
# edges
with open("edges.csv", "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in edges_norm:
        writer.writerow(val)
